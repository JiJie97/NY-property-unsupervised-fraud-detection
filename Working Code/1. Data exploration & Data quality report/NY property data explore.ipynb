# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

start_time = pd.datetime.now()

# %%
mydata = pd.read_csv('NY property data.csv')

# %%
mydata.shape
# Out:
# (1070994, 32)

# %%
numrecords = len(mydata)
print(numrecords)
# Out:
# 1070994

# %%
mydata.dtypes
# Out:
# RECORD        int64
# BBLE         object
# B             int64
# BLOCK         int64
# LOT           int64
# EASEMENT     object
# OWNER        object
# BLDGCL       object
# TAXCLASS     object
# LTFRONT       int64
# LTDEPTH       int64
# EXT          object
# STORIES     float64
# FULLVAL     float64
# AVLAND      float64
# AVTOT       float64
# EXLAND      float64
# EXTOT       float64
# EXCD1       float64
# STADDR       object
# ZIP         float64
# EXMPTCL      object
# BLDFRONT      int64
# BLDDEPTH      int64
# AVLAND2     float64
# AVTOT2      float64
# EXLAND2     float64
# EXTOT2      float64
# EXCD2       float64
# PERIOD       object
# YEAR         object
# VALTYPE      object
# dtype: object

# %%
mydata.head(10).transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4                     5  \
# RECORD                        4                     5                     6
# BBLE                 1000020023            1000030001            1000030002
# B                             1                     1                     1
# BLOCK                         2                     3                     3
# LOT                          23                     1                     2
# EASEMENT                    NaN                   NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION  PARKS AND RECREATION
# BLDGCL                       T2                    Q1                    Q1
# TAXCLASS                      4                     4                     4
# LTFRONT                     793                   323                   496
# LTDEPTH                     551                  1260                    76
# EXT                         NaN                   NaN                   NaN
# STORIES                       2                     1                   NaN
# FULLVAL                3.92e+07             2.723e+08              1.06e+07
# AVLAND               1.5255e+07            1.2105e+08              4.77e+06
# AVTOT                 1.764e+07           1.22535e+08              4.77e+06
# EXLAND               1.5255e+07            1.2105e+08              4.77e+06
# EXTOT                 1.764e+07           1.22535e+08              4.77e+06
# EXCD1                      2191                  2231                  2231
# STADDR                   PIER 6          BATTERY PARK    PETER MINUIT PLAZA
# ZIP                       10004                 10004                 10004
# EXMPTCL                      X1                    X1                    X1
# BLDFRONT                     85                    89                     0
# BLDDEPTH                    551                    57                     0
# AVLAND2              1.3644e+07           1.06349e+08            4.2687e+06
# AVTOT2                1.575e+07           1.07758e+08            4.2687e+06
# EXLAND2              1.3644e+07           1.06349e+08            4.2687e+06
# EXTOT2                1.575e+07           1.07758e+08            4.2687e+06
# EXCD2                       NaN                   NaN                   NaN
# PERIOD                    FINAL                 FINAL                 FINAL
# YEAR                    2010/11               2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR                 AC-TR
#
#                              6                   7                  8  \
# RECORD                       7                   8                  9
# BBLE                1000030003          1000030010         1000041001
# B                            1                   1                  1
# BLOCK                        3                   3                  4
# LOT                          3                  10               1001
# EASEMENT                   NaN                 NaN                NaN
# OWNER     PARKS AND RECREATION  DEPT RE-CITY OF NY  TRZ HOLDINGS, LLC
# BLDGCL                      Q1                  Z9                 R5
# TAXCLASS                     4                   4                  4
# LTFRONT                    180                 362                  0
# LTDEPTH                    370                 177                  0
# EXT                        NaN                 NaN                NaN
# STORIES                      1                   3                 50
# FULLVAL               8.49e+06            2.81e+07        3.94476e+06
# AVLAND              3.8205e+06           1.107e+07             636093
# AVTOT               3.8205e+06          1.2645e+07        1.77514e+06
# EXLAND              3.8205e+06           1.107e+07                  0
# EXTOT               3.8205e+06          1.2645e+07                  0
# EXCD1                     2231                4600                NaN
# STADDR      PETER MINUIT PLAZA      1 SOUTH STREET     1 WATER STREET
# ZIP                      10004               10004              10004
# EXMPTCL                     X1                  X3                NaN
# BLDFRONT                    16                  37                  0
# BLDDEPTH                    19                 227                  0
# AVLAND2             3.5469e+06           9.882e+06             636093
# AVTOT2              3.5469e+06          1.1304e+07        2.04929e+06
# EXLAND2             3.5469e+06           9.882e+06                NaN
# EXTOT2              3.5469e+06          1.1304e+07                NaN
# EXCD2                      NaN                 NaN                NaN
# PERIOD                   FINAL               FINAL              FINAL
# YEAR                   2010/11             2010/11            2010/11
# VALTYPE                  AC-TR               AC-TR              AC-TR
#
#                           9
# RECORD                   10
# BBLE             1000041002
# B                         1
# BLOCK                     4
# LOT                    1002
# EASEMENT                NaN
# OWNER     TRZ HOLDINGS, LLC
# BLDGCL                   R5
# TAXCLASS                  4
# LTFRONT                   0
# LTDEPTH                   0
# EXT                     NaN
# STORIES                  50
# FULLVAL         5.70093e+06
# AVLAND               919276
# AVTOT           2.56542e+06
# EXLAND                    0
# EXTOT                     0
# EXCD1                   NaN
# STADDR       1 WATER STREET
# ZIP                   10004
# EXMPTCL                 NaN
# BLDFRONT                  0
# BLDDEPTH                  0
# AVLAND2              919276
# AVTOT2          2.96162e+06
# EXLAND2                 NaN
# EXTOT2                  NaN
# EXCD2                   NaN
# PERIOD                FINAL
# YEAR                2010/11
# VALTYPE               AC-TR

# %%
mydata.tail().transpose()
# Out:
#                      1070989             1070990             1070991  \
# RECORD               1070990             1070991             1070992
# BBLE              5080500083          5080500086          5080500089
# B                          5                   5                   5
# BLOCK                   8050                8050                8050
# LOT                       83                  86                  89
# EASEMENT                 NaN                 NaN                 NaN
# OWNER            TOBIN, GALE    SHERRI MILINAZZO        JOHN GERVASI
# BLDGCL                    A1                  A1                  A1
# TAXCLASS                   1                   1                   1
# LTFRONT                   60                  62                  53
# LTDEPTH                  120                 228                 273
# EXT                      NaN                 NaN                   G
# STORIES                  2.5                 2.5                   2
# FULLVAL               438000              544000              480000
# AVLAND                 14536                9303               14790
# AVTOT                  23322               14929               22975
# EXLAND                  1620                1620               14728
# EXTOT                   1620                1620               14728
# EXCD1                   1017                1017                1015
# STADDR    142 BENTLEY STREET  146 BENTLEY STREET  150 BENTLEY STREET
# ZIP                    10307               10307               10307
# EXMPTCL                  NaN                 NaN                 NaN
# BLDFRONT                  30                  32                  24
# BLDDEPTH                  26                  26                  32
# AVLAND2                  NaN                 NaN                 NaN
# AVTOT2                   NaN                 NaN                 NaN
# EXLAND2                  NaN                 NaN                 NaN
# EXTOT2                   NaN                 NaN                 NaN
# EXCD2                    NaN                 NaN                1017
# PERIOD                 FINAL               FINAL               FINAL
# YEAR                 2010/11             2010/11             2010/11
# VALTYPE                AC-TR               AC-TR               AC-TR
#
#                      1070992             1070993
# RECORD               1070993             1070994
# BBLE              5080500092          5080500094
# B                          5                   5
# BLOCK                   8050                8050
# LOT                       92                  94
# EASEMENT                 NaN                 NaN
# OWNER            RITA M MOOG      EDWARD DONOHUE
# BLDGCL                    A1                  A1
# TAXCLASS                   1                   1
# LTFRONT                   52                  50
# LTDEPTH                  136                  80
# EXT                      NaN                 NaN
# STORIES                    2                   2
# FULLVAL               543000              473000
# AVLAND                 12388               14061
# AVTOT                  23037               22394
# EXLAND                  1620                1620
# EXTOT                   1620                1620
# EXCD1                   1017                1017
# STADDR    156 BENTLEY STREET  162 BENTLEY STREET
# ZIP                    10307               10307
# EXMPTCL                  NaN                 NaN
# BLDFRONT                  32                  30
# BLDDEPTH                  21                  24
# AVLAND2                  NaN                 NaN
# AVTOT2                   NaN                 NaN
# EXLAND2                  NaN                 NaN
# EXTOT2                   NaN                 NaN
# EXCD2                    NaN                 NaN
# PERIOD                 FINAL               FINAL
# YEAR                 2010/11             2010/11
# VALTYPE                AC-TR               AC-TR

# %%
mydata.describe()
# Out:
#              RECORD             B         BLOCK           LOT       LTFRONT  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   5.354975e+05  3.215427e+00  4.757239e+03  3.647221e+02  3.663530e+01
# std    3.091695e+05  1.201197e+00  3.676579e+03  8.532152e+02  7.403284e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.677492e+05  3.000000e+00  1.555000e+03  2.300000e+01  1.900000e+01
# 50%    5.354975e+05  3.000000e+00  4.047000e+03  4.900000e+01  2.500000e+01
# 75%    8.032458e+05  4.000000e+00  6.898000e+03  1.430000e+02  4.000000e+01
# max    1.070994e+06  5.000000e+00  1.635000e+04  9.978000e+03  9.999000e+03
#
#             LTDEPTH       STORIES       FULLVAL        AVLAND         AVTOT  \
# count  1.070994e+06  1.014730e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   8.886159e+01  5.006918e+00  8.742645e+05  8.506792e+04  2.272382e+05
# std    7.639628e+01  8.365707e+00  1.158243e+07  4.057260e+06  6.877529e+06
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.000000e+01  2.000000e+00  3.040000e+05  9.180000e+03  1.837400e+04
# 50%    1.000000e+02  2.000000e+00  4.470000e+05  1.367800e+04  2.534000e+04
# 75%    1.000000e+02  3.000000e+00  6.190000e+05  1.974000e+04  4.543800e+04
# max    9.999000e+03  1.190000e+02  6.150000e+09  2.668500e+09  4.668309e+09
#
#        ...         EXTOT          EXCD1           ZIP      BLDFRONT  \
# count  ...  1.070994e+06  638488.000000  1.041104e+06  1.070994e+06
# mean   ...  9.118698e+04    1602.014232  1.092396e+04  2.304277e+01
# std    ...  6.508403e+06    1384.226741  5.284208e+02  3.557970e+01
# min    ...  0.000000e+00    1010.000000  1.000100e+04  0.000000e+00
# 25%    ...  0.000000e+00    1017.000000  1.031400e+04  1.500000e+01
# 50%    ...  1.620000e+03    1017.000000  1.121400e+04  2.000000e+01
# 75%    ...  2.090000e+03    1017.000000  1.136400e+04  2.400000e+01
# max    ...  4.668309e+09    7170.000000  3.380300e+04  7.575000e+03
#
#            BLDDEPTH       AVLAND2        AVTOT2       EXLAND2        EXTOT2  \
# count  1.070994e+06  2.827260e+05  2.827320e+05  8.744900e+04  1.308280e+05
# mean   3.992284e+01  2.462357e+05  7.139114e+05  3.512357e+05  6.567683e+05
# std    4.270715e+01  6.178963e+06  1.165253e+07  1.080221e+07  1.607251e+07
# min    0.000000e+00  3.000000e+00  3.000000e+00  1.000000e+00  7.000000e+00
# 25%    2.600000e+01  5.705000e+03  3.391200e+04  2.090000e+03  2.870000e+03
# 50%    3.900000e+01  2.014500e+04  7.996250e+04  3.048000e+03  3.706200e+04
# 75%    5.000000e+01  6.264000e+04  2.405510e+05  3.177900e+04  1.068408e+05
# max    9.393000e+03  2.371005e+09  4.501180e+09  2.371005e+09  4.501180e+09
#
#               EXCD2
# count  92948.000000
# mean    1364.041679
# std     1094.705653
# min     1011.000000
# 25%     1017.000000
# 50%     1017.000000
# 75%     1017.000000
# max     7160.000000
#
# [8 rows x 21 columns]

# %%
df = mydata.describe()
uni_val= pd.DataFrame()

# %%
uni_val

# %%
tmp = []
name = []

# %%
for i in df.columns:
    tmp.append(len(mydata[i].unique()))
    name.append(i)
tmp = pd.Series(tmp)
name = pd.Series(name)

# %%
val_0 = pd.DataFrame()
tmp = []
name = []

# %%
for i in df.columns:
    tmp.append(sum(mydata[i]==0))
    name.append(i)
tmp = pd.Series(tmp)
name = pd.Series(name)

# %%
val_0

# %%
val_0['Column'] = name
val_0['Zero values'] = tmp

# %%
val_0

# %%
mydata.describe().transpose()

# %%
mydata.isna().sum()

# %%
mydata.count().count()

# %%
mydata['RECORD'].unique()

# %%
len(mydata['RECORD'])

# %%
# mydata.set_index('RECORD', inplace = True)

# %%
len(mydata['BBLE'].unique())

# %%
mydata['BBLE'].head()

# %%
len(mydata['B'].unique())

# %%
mydata['B'].value_counts()

# %%
mydata['B'].count() * 100 / numrecords
# Out:
# 100.0

# %%
mydata['BLOCK'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['BLOCK'].unique())
# Out:
# 13984

# %%
mydata['BLOCK'].value_counts()
# Out:
# 3944     3888
# 16       3786
# 3943     3424
# 3938     2794
# 1171     2535
#          ...
# 15880       1
# 15895       1
# 15892       1
# 10119       1
# 9067        1
# Name: BLOCK, Length: 13984, dtype: int64

# %%
mydata['BLOCK'].min()
# Out:
# 1

# %%
mydata['LOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['LOT'].unique())
# Out:
# 6366

# %%
mydata['LOT'].value_counts()
# Out:
# 1       24367
# 20      12294
# 15      12171
# 12      12143
# 14      12074
#         ...
# 5547        1
# 8075        1
# 6883        1
# 5460        1
# 9108        1
# Name: LOT, Length: 6366, dtype: int64

# %%
mydata['LOT'].min()
# Out:
# 1

# %%
mydata['EASEMENT'].count() * 100 / numrecords
# Out:
# 0.4328689049611856

# %%
len(mydata['EASEMENT'].unique())
# Out:
# 13

# %%
mydata['EASEMENT'].value_counts()
# Out:
# E    4148
# F     296
# G     102
# H      33
# N      19
# I      16
# J       8
# K       5
# L       3
# P       3
# M       2
# U       1
# Name: EASEMENT, dtype: int64

# %%
plot = sns.countplot(x='EASEMENT', data = mydata)

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='OWNER', data = mydata, order = mydata['OWNER'].value_counts().head(15).index)
plt.savefig('hist.png')

# %%
mydata['OWNER'].count() * 100 / numrecords
# Out:
# 97.03593110699033

# %%
len(mydata['OWNER'].unique())
# Out:
# 863347

# %%
owner = pd.DataFrame(mydata['OWNER'].value_counts())

# %%
owner.reset_index(inplace=True)

# %%
owner
# Out:
#                         index  OWNER
# 0       PARKCHESTER PRESERVAT   6020
# 1        PARKS AND RECREATION   4255
# 2                        DCAS   2169
# 3        HOUSING PRESERVATION   1904
# 4            CITY OF NEW YORK   1450
# ...                       ...    ...
# 863341            ROMAN DELSI      1
# 863342   2386 ARTHUR AVE HDFC      1
# 863343        GLORIA MARCHESE      1
# 863344    KELLY, PATRICK J JR      1
# 863345        MOHAN VISHNUPAD      1
#
# [863346 rows x 2 columns]

# %%
df = mydata['OWNER'].value_counts().head(15)

# %%
mydata
# Out:
#           RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER  \
# 0              1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS
# 1              2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS
# 2              3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI
# 3              4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES
# 4              5  1000030001  1      3    1      NaN   PARKS AND RECREATION
# ...          ...         ... ..    ...  ...      ...                    ...
# 1070989  1070990  5080500083  5   8050   83      NaN            TOBIN, GALE
# 1070990  1070991  5080500086  5   8050   86      NaN       SHERRI MILINAZZO
# 1070991  1070992  5080500089  5   8050   89      NaN           JOHN GERVASI
# 1070992  1070993  5080500092  5   8050   92      NaN            RITA M MOOG
# 1070993  1070994  5080500094  5   8050   94      NaN         EDWARD DONOHUE
#
#         BLDGCL TAXCLASS  LTFRONT  ...  BLDFRONT BLDDEPTH      AVLAND2  \
# 0           P7        4      500  ...         0        0    3775500.0
# 1           Z9        4       27  ...         0        0   11111400.0
# 2           Y7        4      709  ...       709      564   32321790.0
# 3           T2        4      793  ...        85      551   13644000.0
# 4           Q1        4      323  ...        89       57  106348680.0
# ...        ...      ...      ...  ...       ...      ...          ...
# 1070989     A1        1       60  ...        30       26          NaN
# 1070990     A1        1       62  ...        32       26          NaN
# 1070991     A1        1       53  ...        24       32          NaN
# 1070992     A1        1       52  ...        32       21          NaN
# 1070993     A1        1       50  ...        30       24          NaN
#
#               AVTOT2      EXLAND2       EXTOT2   EXCD2  PERIOD     YEAR  \
# 0          8613000.0    3775500.0    8613000.0     NaN   FINAL  2010/11
# 1         80690400.0   11111400.0   80690400.0     NaN   FINAL  2010/11
# 2         40179510.0   32321790.0   40179510.0     NaN   FINAL  2010/11
# 3         15750000.0   13644000.0   15750000.0     NaN   FINAL  2010/11
# 4        107758350.0  106348680.0  107758350.0     NaN   FINAL  2010/11
# ...              ...          ...          ...     ...     ...      ...
# 1070989          NaN          NaN          NaN     NaN   FINAL  2010/11
# 1070990          NaN          NaN          NaN     NaN   FINAL  2010/11
# 1070991          NaN          NaN          NaN  1017.0   FINAL  2010/11
# 1070992          NaN          NaN          NaN     NaN   FINAL  2010/11
# 1070993          NaN          NaN          NaN     NaN   FINAL  2010/11
#
#         VALTYPE
# 0         AC-TR
# 1         AC-TR
# 2         AC-TR
# 3         AC-TR
# 4         AC-TR
# ...         ...
# 1070989   AC-TR
# 1070990   AC-TR
# 1070991   AC-TR
# 1070992   AC-TR
# 1070993   AC-TR
#
# [1070994 rows x 32 columns]

# %%
mydata['OWNER'].value_counts().head(15).plot(kind='bar',fontsize = 14)

# %%
mydata['BLDGCL'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['BLDGCL'].unique())
# Out:
# 200

# %%
mydata['BLDGCL'].value_counts().count()
# Out:
# 200

# %%
mydata[mydata['BLDGCL'] == 0]
# Out:
# Empty DataFrame
# Columns: [RECORD, BBLE, B, BLOCK, LOT, EASEMENT, OWNER, BLDGCL, TAXCLASS, LTFRONT, LTDEPTH, EXT, STORIES, FULLVAL, AVLAND, AVTOT, EXLAND, EXTOT, EXCD1, STADDR, ZIP, EXMPTCL, BLDFRONT, BLDDEPTH, AVLAND2, AVTOT2, EXLAND2, EXTOT2, EXCD2, PERIOD, YEAR, VALTYPE]
# Index: []
#
# [0 rows x 32 columns]

# %%
help(plot.set_yscale)
# Out:
# Help on method set_yscale in module matplotlib.axes._base:
#
# set_yscale(value, **kwargs) method of matplotlib.axes._subplots.AxesSubplot instance
#     Set the y-axis scale.
#
#     Parameters
#     ----------
#     value : {"linear", "log", "symlog", "logit", ...}
#         The axis scale type to apply.
#
#     **kwargs
#         Different keyword arguments are accepted, depending on the scale.
#         See the respective class keyword arguments:
#
#         - `matplotlib.scale.LinearScale`
#         - `matplotlib.scale.LogScale`
#         - `matplotlib.scale.SymmetricalLogScale`
#         - `matplotlib.scale.LogitScale`
#
#
#     Notes
#     -----
#     By default, Matplotlib supports the above mentioned scales.
#     Additionally, custom scales may be registered using
#     `matplotlib.scale.register_scale`. These scales can then also
#     be used here.

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='EASEMENT', data = mydata, order = mydata['EASEMENT'].value_counts().index)

plt.savefig('hist.png')

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
sns.countplot(x = 'BLDGCL', data = mydata, order = mydata['BLDGCL'].value_counts().head(15).index)

# %%
mydata['TAXCLASS'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['TAXCLASS'].unique())
# Out:
# 11

# %%
mydata['TAXCLASS'].value_counts()
# Out:
# 1     660721
# 2     188612
# 4     104310
# 2A     40574
# 1B     24738
# 1A     21667
# 2B     13964
# 2C     10795
# 3       4638
# 1C       946
# 1D        29
# Name: TAXCLASS, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=1.5)
plot = sns.countplot(x = 'TAXCLASS', data = mydata, order = mydata['TAXCLASS'].value_counts().index)
plot.set_yscale('log')

# %%
mydata['LTFRONT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sum(mydata['LTFRONT']<=200)/len(mydata['LTFRONT'])
# Out:
# 0.9846684481892523

# %%
my_ltfront = mydata[mydata['LTFRONT']<=200]

# %%
sns.distplot(my_ltfront['LTFRONT'])

# %%
sns.boxplot(x='LTFRONT', data=mydata)

# %%
sns.distplot(mydata['LTFRONT'])

# %%
xhigh = 200
plt.xlim(0,xhigh)
temp = mydata[mydata['LTFRONT'] <= xhigh]
sns.distplot(temp['LTFRONT'],bins=100, kde=True)

# %%
len(mydata[mydata['LTFRONT']==0])
# Out:
# 169108

# %%
len(mydata[mydata['LTFRONT']==1])
# Out:
# 839

# %%
len(mydata[mydata["LTFRONT"]==2])
# Out:
# 762

# %%
mydata['LTDEPTH'].value_counts()
# Out:
# 100     464541
# 0       170128
# 95       31612
# 90       20294
# 80       16671
#          ...
# 1471         1
# 1224         1
# 820          1
# 2253         1
# 4720         1
# Name: LTDEPTH, Length: 1370, dtype: int64

# %%
mydata['LTDEPTH'].count() * 100 / numrecords
# Out:
# 100.0

# %%
my_dep = mydata[mydata['LTDEPTH']<=200]

# %%
my_dep['LTDEPTH'].count() * 100 / numrecords
# Out:
# 98.2461152910287

# %%
sns.boxplot(x='LTDEPTH', data=mydata)

# %%
xhigh = 200
plt.xlim(0,xhigh)
temp = mydata[mydata['LTDEPTH'] <= xhigh]
plot = sns.distplot(temp['LTDEPTH'],bins=100, kde=True)
plot.set_yscale('log')

# %%
sns.distplot(mydata['LTDEPTH'],kde=False)

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['LTDEPTH'] <= xhigh]
sns.distplot(temp['LTDEPTH'],bins=100, kde=True)

# %%
len(mydata[mydata['LTDEPTH']==0])
# Out:
# 170128

# %%
len(mydata[mydata['LTDEPTH']==1])
# Out:
# 127

# %%
len(mydata[mydata["LTDEPTH"]==2])
# Out:
# 84

# %%
mydata['LTDEPTH'].value_counts()
# Out:
# 100     464541
# 0       170128
# 95       31612
# 90       20294
# 80       16671
# 99       11390
# 97       10227
# 75       10161
# 102       9607
# 96        9329
# 110       8943
# 98        8757
# 105       8522
# 101       7697
# 120       7683
# 85        7328
# 125       7324
# 103       6995
# 92        6734
# 200       6692
# 94        5971
# 93        4964
# 107       4810
# 109       4528
# 60        4522
# 50        4505
# 87        4449
# 104       4414
# 150       4393
# 114       4246
#          ...
# 1251         1
# 1825         1
# 1231         1
# 2866         1
# 838          1
# 819          1
# 1860         1
# 4934         1
# 2231         1
# 2885         1
# 8000         1
# 835          1
# 1209         1
# 832          1
# 5948         1
# 1477         1
# 1853         1
# 1215         1
# 3900         1
# 1476         1
# 1218         1
# 827          1
# 2875         1
# 1472         1
# 1222         1
# 1471         1
# 1224         1
# 820          1
# 2253         1
# 4720         1
# Name: LTDEPTH, Length: 1370, dtype: int64

# %%
mydata['EXT'].value_counts()
# Out:
# G     266970
# E      49442
# EG     37893
# Name: EXT, dtype: int64

# %%
plot = sns.countplot(x='EXT', data = mydata, order = mydata['EXT'].value_counts().index)

# %%
mydata['EXT'].count() * 100 / numrecords
# Out:
# 33.081884679092504

# %%
mydata['STORIES'].count() * 100 / numrecords
# Out:
# 94.74656253909919

# %%
sum(pd.isnull(mydata['STORIES']))
# Out:
# 56264

# %%
sns.boxplot(x='STORIES', data=mydata)
plt.savefig("boxplot.png")

# %%
len(mydata[mydata['STORIES'] == 0])
# Out:
# 0

# %%
my_stor = mydata[mydata['STORIES'] <= 50]

# %%
my_stor['STORIES'].count()/numrecords
# Out:
# 0.9427606503864634

# %%
sns.boxplot(x='STORIES', data=mydata)

# %%
xhigh = 50
temp = mydata[mydata['STORIES'] > 0]
temp.count()
plt.xlim(0,xhigh)
temp = temp[temp['STORIES'] <= xhigh]
plot = sns.distplot(temp['STORIES'],bins=51, kde=False)
plot.set_yscale('log')

# %%
len(mydata[mydata['STORIES'] == 1])
# Out:
# 96706

# %%
mydata['STORIES'].value_counts()
# Out:
# 2.0      415092
# 3.0      130127
# 1.0       96706
# 2.5       82292
# 4.0       38342
# 6.0       30936
# 5.0       25971
# 1.5       24770
# 2.7       13595
# 12.0      12198
# 8.0       11953
# 7.0       11899
# 1.6        8954
# 9.0        7343
# 13.0       7330
# 16.0       5428
# 1.7        5239
# 21.0       4885
# 19.0       4866
# 11.0       4459
# 15.0       4270
# 10.0       3758
# 17.0       3457
# 14.0       3368
# 20.0       3142
# 32.0       3127
# 30.0       2905
# 42.0       2875
# 31.0       2583
# 27.0       2333
#           ...
# 6.7          12
# 59.0         12
# 3.6          11
# 47.0         10
# 4.7          10
# 1.9          10
# 74.0          6
# 3.3           5
# 100.0         5
# 9.5           4
# 62.0          3
# 2.8           3
# 1.1           3
# 1.3           3
# 8.5           3
# 68.0          2
# 2.9           2
# 5.7           2
# 1.4           2
# 63.0          2
# 2.4           2
# 119.0         1
# 82.0          1
# 4.2           1
# 114.0         1
# 76.0          1
# 2.1           1
# 61.0          1
# 85.0          1
# 78.0          1
# Name: STORIES, Length: 111, dtype: int64

# %%
mydata['FULLVAL'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='FULLVAL', data=mydata)
plt.savefig("boxplot.png")

# %%
sns.distplot(mydata['FULLVAL'],kde=False)
plt.savefig('dist bad.png')

# %%
len(mydata[mydata['FULLVAL']==0])
# Out:
# 13007

# %%
len(mydata[mydata['FULLVAL']==1])
# Out:
# 0

# %%
len(mydata[mydata["FULLVAL"]==2])
# Out:
# 0

# %%
temp = mydata[mydata['FULLVAL'] >= 0]
ax = sns.distplot(temp['FULLVAL'],bins=100, kde=False)
ax.set_yscale('log')
plt.savefig('log.png')

# %%
temp = mydata[mydata['FULLVAL'] >= 0]
ax = sns.distplot(temp['FULLVAL'],bins=100, kde=False)
ax.set_yscale('log')
ax.set_xscale('log')
plt.savefig('loglog.png')

# %%
xhigh = 1500000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=15, kde=True)
plt.savefig('dist good.png')

# %%
mydata[mydata['FULLVAL'] <= 1500000]['FULLVAL'].count()/numrecords
# Out:
# 0.9490109188286769

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=10, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=1000, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 1000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=100, kde=True)

# %%
xhigh = 100000
plt.xlim(0,xhigh)
temp = mydata[(mydata['FULLVAL'] <= xhigh) & (mydata['FULLVAL']) > 0]
sns.distplot(temp['FULLVAL'],bins=100, kde=False)

# %%
len(mydata[mydata['FULLVAL'] == 0])
# Out:
# 13007

# %%
mydata['AVLAND'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='AVLAND', data=mydata)

# %%
mydata['AVLAND']
# Out:
# 0            4225500.0
# 1           14310000.0
# 2           39008700.0
# 3           15255000.0
# 4          121050000.0
#               ...
# 1070989        14536.0
# 1070990         9303.0
# 1070991        14790.0
# 1070992        12388.0
# 1070993        14061.0
# Name: AVLAND, Length: 1070994, dtype: float64

# %%
help(plot.set_yscale)
# Out:
# Help on method set_yscale in module matplotlib.axes._base:
#
# set_yscale(value, **kwargs) method of matplotlib.axes._subplots.AxesSubplot instance
#     Set the y-axis scale.
#
#     Parameters
#     ----------
#     value : {"linear", "log", "symlog", "logit", ...}
#         The axis scale type to apply.
#
#     **kwargs
#         Different keyword arguments are accepted, depending on the scale.
#         See the respective class keyword arguments:
#
#         - `matplotlib.scale.LinearScale`
#         - `matplotlib.scale.LogScale`
#         - `matplotlib.scale.SymmetricalLogScale`
#         - `matplotlib.scale.LogitScale`
#
#
#     Notes
#     -----
#     By default, Matplotlib supports the above mentioned scales.
#     Additionally, custom scales may be registered using
#     `matplotlib.scale.register_scale`. These scales can then also
#     be used here.

# %%
plot = sns.distplot(mydata['AVLAND'],bins=30, kde=False)
plot.set_yscale('symlog')

# %%
sns.distplot(mydata['AVLAND'],kde=True)

# %%
len(mydata[mydata['AVLAND']==0])
# Out:
# 13009

# %%
len(mydata[mydata['AVLAND']==1])
# Out:
# 3

# %%
len(mydata[mydata["AVLAND"]==2])
# Out:
# 13

# %%
mydata[mydata['AVLAND']<=50000]['AVLAND'].count()/numrecords
# Out:
# 0.9052721117018396

# %%
xhigh = 50000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND'] <= xhigh]
sns.distplot(temp['AVLAND'],bins=100, kde=True)

# %%
mydata['AVTOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='AVTOT', data=mydata)

# %%
mydata[mydata['AVTOT']<=100000]['AVTOT'].count()/numrecords
# Out:
# 0.8605239618522607

# %%
xhigh = 100000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT'] <= xhigh]
sns.distplot(temp['AVTOT'],bins=50, kde=True)

# %%
len(mydata[mydata['AVTOT']==0])
# Out:
# 13007

# %%
len(mydata[mydata['AVTOT']==1])
# Out:
# 3

# %%
len(mydata[mydata["AVTOT"]==2])
# Out:
# 2

# %%
mydata['EXLAND'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='EXLAND', data=mydata)

# %%
mydata[mydata['EXLAND']<=20000]['EXLAND'].count()/numrecords
# Out:
# 0.9682472544197259

# %%
xhigh = 20000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXLAND'] <= xhigh]
plot = sns.distplot(temp['EXLAND'],bins=50, kde=False)
plot.set_yscale('log')

# %%
len(mydata[mydata['EXLAND']==0])
# Out:
# 491699

# %%
len(mydata[mydata['EXLAND']==1])
# Out:
# 8

# %%
len(mydata[mydata["EXLAND"]==2])
# Out:
# 15

# %%
mydata['EXTOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='EXTOT', data=mydata)

# %%
mydata[mydata['EXTOT']<=20000]['EXTOT'].count()/numrecords
# Out:
# 0.9040078655902835

# %%
xhigh = 20000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT'] <= xhigh]
plot = sns.distplot(temp['EXTOT'],bins=50, kde=False)
plot.set_yscale('log')

# %%
len(mydata[mydata['EXTOT']==0])
# Out:
# 432572

# %%
len(mydata[mydata['EXTOT']==1])
# Out:
# 10

# %%
len(mydata[mydata["EXTOT"]==2])
# Out:
# 2

# %%
mydata['EXCD1'].count() * 100 / numrecords
# Out:
# 59.616393742635346

# %%
sns.boxplot(x='EXCD1', data=mydata)

# %%
mydata[mydata['EXCD1']<=10000]['EXCD1'].count()/numrecords
# Out:
# 0.5961639374263534

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD1'] <= xhigh]
plot = sns.distplot(temp['EXCD1'],bins=30, kde=False)
plot.set_yscale('log')

# %%
len(mydata[mydata['EXCD1']==0])
# Out:
# 0

# %%
len(mydata[mydata['EXCD1']==1])
# Out:
# 0

# %%
len(mydata[mydata["EXCD1"]==2])
# Out:
# 0

# %%
mydata['STADDR'].count() * 100 / numrecords
# Out:
# 99.93688106562689

# %%
len(mydata['STADDR'].unique())
# Out:
# 839281

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=1)
plot = sns.countplot(x='STADDR', data = mydata, order = mydata['STADDR'].value_counts().head(20).index)

plt.savefig('hist.png')

# %%
my_sta = pd.DataFrame(mydata['STADDR'].value_counts().head(20))

# %%
my_sta
# Out:
#                          STADDR
# 501 SURF AVENUE             902
# 330 EAST 38 STREET          817
# 322 WEST 57 STREET          720
# 155 WEST 68 STREET          671
# 20 WEST 64 STREET           657
# 1 IRVING PLACE              650
# 220 RIVERSIDE BOULEVARD     628
# 360 FURMAN STREET           599
# 200 EAST 66 STREET          585
# 30 WEST 63 STREET           562
# 350 WEST 42 STREET          556
# 2 BAY CLUB DRIVE            556
# 200 RECTOR PLACE            549
# 301 EAST 79 STREET          538
# 350 WEST 50 STREET          498
# 630 1 AVENUE                488
# 635 WEST 42 STREET          483
# 88 GREENWICH STREET         453
# 150 WEST 51 STREET          447
# 99 JOHN STREET              445

# %%
mydata['ZIP'].count() * 100 / numrecords
# Out:
# 97.20913469169761

# %%
len(mydata['ZIP'].unique())
# Out:
# 197

# %%
my_zip = pd.DataFrame(mydata['ZIP'].value_counts().head(20))

# %%
my_zip.iloc[:,0]
# Out:
# 10314.0    24606
# 11234.0    20001
# 10312.0    18127
# 10462.0    16905
# 10306.0    16578
# 11236.0    15678
# 11385.0    14921
# 11229.0    12793
# 11211.0    12710
# 11207.0    12293
# 11215.0    11834
# 11235.0    11312
# 11203.0    11241
# 11208.0    11139
# 11204.0    11061
# 10469.0    11030
# 11214.0    10886
# 11223.0    10741
# 10305.0    10625
# 11434.0    10505
# Name: ZIP, dtype: int64

# %%
mydata['EXMPTCL'].count() * 100 / numrecords
# Out:
# 1.4546299979271593

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=1)
plot = sns.countplot(x='EXMPTCL', data = mydata, order = mydata['EXMPTCL'].value_counts().index)
plot.set_yscale('log')
plt.savefig('hist.png')

# %%
len(mydata['EXMPTCL'].unique())
# Out:
# 15

# %%
mydata['EXMPTCL'].value_counts()
# Out:
# X1    6912
# X5    5208
# X7     820
# X2     770
# X6     764
# X4     441
# X8     292
# X3     259
# X9     108
# R4       1
# 5        1
# KI       1
# VI       1
# A9       1
# Name: EXMPTCL, dtype: int64

# %%
mydata['BLDFRONT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='BLDFRONT', data=mydata)

# %%
mydata[mydata['BLDFRONT']<=200]['BLDFRONT'].count()/numrecords
# Out:
# 0.9955742048975065

# %%
xhigh = 200
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDFRONT'] <= xhigh]
plot = sns.distplot(temp['BLDFRONT'],bins=50, kde=False)
plot.set_yscale('log')

# %%
len(mydata[mydata['BLDFRONT']==0])
# Out:
# 228815

# %%
len(mydata[mydata['BLDFRONT']==1])
# Out:
# 77

# %%
len(mydata[mydata["BLDFRONT"]==2])
# Out:
# 21

# %%
mydata['BLDDEPTH'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='BLDDEPTH', data=mydata)

# %%
mydata[mydata['BLDDEPTH']<=300]['BLDDEPTH'].count()/numrecords
# Out:
# 0.9982483561999413

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDDEPTH'] <= xhigh]
plot = sns.distplot(temp['BLDDEPTH'],bins=50, kde=False)
plot.set_yscale('log')

# %%
len(mydata[mydata['BLDDEPTH']==0])
# Out:
# 228853

# %%
len(mydata[mydata['BLDDEPTH']==1])
# Out:
# 59

# %%
len(mydata[mydata["BLDDEPTH"]==2])
# Out:
# 10

# %%
mydata['AVLAND2'].count() * 100 / numrecords
# Out:
# 26.398467218303743

# %%
mydata['AVLAND2'].count() * 100/ numrecords
# Out:
# 26.398467218303743

# %%
sns.boxplot(x='AVLAND2', data=mydata)

# %%
mydata[mydata['AVLAND2']<=300000]['AVLAND2'].count()/numrecords
# Out:
# 0.24150368722887336

# %%
xhigh = 300000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND2'] <= xhigh]
plot= sns.distplot(temp['AVLAND2'],bins=50, kde=True)
plot.set_yscale('log')

# %%
mydata['AVTOT2'].count() * 100 / numrecords
# Out:
# 26.399027445531907

# %%
sns.boxplot(x='AVTOT2', data=mydata)

# %%
mydata[mydata['AVTOT2']<=1000000]['AVTOT2'].count()/numrecords
# Out:
# 0.2418678349271798

# %%
xhigh = 1000000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT2'] <= xhigh]
plot = sns.distplot(temp['AVTOT2'],bins=50, kde=True)
plot.set_yscale('log')

# %%
mydata['EXLAND2'].count() * 100 / numrecords
# Out:
# 8.165218479281863

# %%
mydata[mydata['EXLAND2']<=50000]['EXLAND2'].count()/numrecords
# Out:
# 0.0641814986825323

# %%
sns.boxplot(x='EXLAND2', data =mydata)

# %%
xhigh = 50000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXLAND2'] <= xhigh]
plot = sns.distplot(temp['EXLAND2'],bins=50, kde=False)
plot.set_yscale('log')

# %%
mydata['EXTOT2'].count() * 100 / numrecords
# Out:
# 12.215567967701032

# %%
sns.boxplot(x='EXTOT2', data=mydata)

# %%
xhigh = 300000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT2'] <= xhigh]
plot = sns.distplot(temp['EXTOT2'],bins=100, kde=False)
plot.set_yscale('log')

# %%
mydata['EXCD2'].count() * 100 / numrecords
# Out:
# 8.678666733893934

# %%
sns.boxplot(x='EXCD2', data=mydata)

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD2'] <= xhigh]
plot = sns.distplot(temp['EXCD2'],bins=30, kde=False)

plot.set_yscale('log')

# %%
mydata['PERIOD'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['PERIOD'].unique())
# Out:
# 1

# %%
mydata['PERIOD'].value_counts()
# Out:
# FINAL    1070994
# Name: PERIOD, dtype: int64

# %%
mydata['YEAR'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['YEAR'].unique())
# Out:
# 1

# %%
mydata['YEAR'].value_counts()
# Out:
# 2010/11    1070994
# Name: YEAR, dtype: int64

# %%
mydata['VALTYPE'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['VALTYPE'].unique())
# Out:
# 1

# %%
mydata['VALTYPE'].value_counts()
# Out:
# AC-TR    1070994
# Name: VALTYPE, dtype: int64

# %%
len(mydata[mydata['LTFRONT'] == 0])
# Out:
# 169108

# %%
len(mydata[mydata['LTDEPTH'] == 0])
# Out:
# 170128

# %%
len(mydata[(mydata['LTFRONT'] == 0) & (mydata['LTFRONT'] == 0)])
# Out:
# 169108

# %%
temp = mydata[(mydata['LTFRONT'] == 0) & (mydata['LTFRONT'] == 0)]

# %%
temp['BLDFRONT'].value_counts()
# Out:
# 0      150872
# 20        835
# 100       821
# 200       696
# 25        655
# 18        620
# 160       585
# 116       561
# 24        560
# 175       453
# 190       444
# 128       444
# 22        439
# 151       437
# 97        435
# 115       415
# 261       400
# 132       386
# 201       372
# 134       358
# 21        354
# 75        339
# 23        305
# 78        286
# 110       272
# 70        271
# 19        265
# 146       253
# 202       230
# 50        226
#         ...
# 264         2
# 13          2
# 206         2
# 180         2
# 182         2
# 214         2
# 532         2
# 220         2
# 870         1
# 982         1
# 158         1
# 81          1
# 179         1
# 900         1
# 133         1
# 243         1
# 6           1
# 111         1
# 48          1
# 421         1
# 199         1
# 265         1
# 94          1
# 222         1
# 195         1
# 140         1
# 155         1
# 95          1
# 106         1
# 780         1
# Name: BLDFRONT, Length: 154, dtype: int64

# %%
temp['BLDDEPTH'].value_counts()
# Out:
# 0       150858
# 100       1262
# 97         733
# 596        584
# 106        563
# 24         538
# 125        491
# 146        453
# 172        445
# 179        413
# 149        412
# 185        400
# 48         385
# 60         381
# 99         361
# 115        358
# 298        347
# 65         333
# 64         320
# 221        315
# 98         282
# 50         277
# 135        274
# 102        269
# 198        251
# 43         251
# 42         234
# 327        229
# 40         212
# 70         206
#          ...
# 390          1
# 21           1
# 530          1
# 525          1
# 126          1
# 507          1
# 147          1
# 109          1
# 375          1
# 405          1
# 208          1
# 320          1
# 3390         1
# 1980         1
# 439          1
# 182          1
# 225          1
# 171          1
# 228          1
# 103          1
# 492          1
# 493          1
# 292          1
# 622          1
# 544          1
# 160          1
# 413          1
# 409          1
# 535          1
# 511          1
# Name: BLDDEPTH, Length: 169, dtype: int64

# %%
mydata['EASEMENT'].value_counts().head(20).plot(kind='bar',logy=True)

# %%
print('duration: ', pd.datetime.now() - start_time)
# Out:
# duration:  0:01:47.711317

# %%
len(mydata)
# Out:
# 1070994

# %%
len(mydata.transpose())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-257-12716dcc1ceb> in <module>
# ----> 1 len(mydata.transpose())
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in transpose(self, *args, **kwargs)
#    2754         kids          0     0
#    2755
# -> 2756         When the DataFrame has mixed dtypes, we get a transposed DataFrame with
#    2757         the `object` dtype:
#    2758
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in transpose(self, *args, **kwargs)
#     733
#     734         nv.validate_transpose(tuple(), kwargs)
# --> 735         return self._constructor(new_values, **new_axes).__finalize__(self)
#     736
#     737     def swapaxes(self, axis1, axis2, copy=True):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     438                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     439             else:
# --> 440                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     441
#     442         # For data is list-like, or Iterable (will consume into list)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     196             for n in range(len(dvals_list)):
#     197                 if isinstance(dvals_list[n], np.ndarray):
# --> 198                     dvals_list[n] = dvals_list[n].reshape(1, -1)
#     199
#     200             from pandas.core.internals.blocks import make_block
#
# KeyboardInterrupt:

# %%
mydata.transpose()
# Out:
#                         0                      1                      2        \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                         3                     4                     5        \
# RECORD                        4                     5                     6
# BBLE                 1000020023            1000030001            1000030002
# B                             1                     1                     1
# BLOCK                         2                     3                     3
# LOT                          23                     1                     2
# EASEMENT                    NaN                   NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION  PARKS AND RECREATION
# BLDGCL                       T2                    Q1                    Q1
# TAXCLASS                      4                     4                     4
# LTFRONT                     793                   323                   496
# LTDEPTH                     551                  1260                    76
# EXT                         NaN                   NaN                   NaN
# STORIES                       2                     1                   NaN
# FULLVAL                3.92e+07             2.723e+08              1.06e+07
# AVLAND               1.5255e+07            1.2105e+08              4.77e+06
# AVTOT                 1.764e+07           1.22535e+08              4.77e+06
# EXLAND               1.5255e+07            1.2105e+08              4.77e+06
# EXTOT                 1.764e+07           1.22535e+08              4.77e+06
# EXCD1                      2191                  2231                  2231
# STADDR                   PIER 6          BATTERY PARK    PETER MINUIT PLAZA
# ZIP                       10004                 10004                 10004
# EXMPTCL                      X1                    X1                    X1
# BLDFRONT                     85                    89                     0
# BLDDEPTH                    551                    57                     0
# AVLAND2              1.3644e+07           1.06349e+08            4.2687e+06
# AVTOT2                1.575e+07           1.07758e+08            4.2687e+06
# EXLAND2              1.3644e+07           1.06349e+08            4.2687e+06
# EXTOT2                1.575e+07           1.07758e+08            4.2687e+06
# EXCD2                       NaN                   NaN                   NaN
# PERIOD                    FINAL                 FINAL                 FINAL
# YEAR                    2010/11               2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR                 AC-TR
#
#                        6                   7                  8        \
# RECORD                       7                   8                  9
# BBLE                1000030003          1000030010         1000041001
# B                            1                   1                  1
# BLOCK                        3                   3                  4
# LOT                          3                  10               1001
# EASEMENT                   NaN                 NaN                NaN
# OWNER     PARKS AND RECREATION  DEPT RE-CITY OF NY  TRZ HOLDINGS, LLC
# BLDGCL                      Q1                  Z9                 R5
# TAXCLASS                     4                   4                  4
# LTFRONT                    180                 362                  0
# LTDEPTH                    370                 177                  0
# EXT                        NaN                 NaN                NaN
# STORIES                      1                   3                 50
# FULLVAL               8.49e+06            2.81e+07        3.94476e+06
# AVLAND              3.8205e+06           1.107e+07             636093
# AVTOT               3.8205e+06          1.2645e+07        1.77514e+06
# EXLAND              3.8205e+06           1.107e+07                  0
# EXTOT               3.8205e+06          1.2645e+07                  0
# EXCD1                     2231                4600                NaN
# STADDR      PETER MINUIT PLAZA      1 SOUTH STREET     1 WATER STREET
# ZIP                      10004               10004              10004
# EXMPTCL                     X1                  X3                NaN
# BLDFRONT                    16                  37                  0
# BLDDEPTH                    19                 227                  0
# AVLAND2             3.5469e+06           9.882e+06             636093
# AVTOT2              3.5469e+06          1.1304e+07        2.04929e+06
# EXLAND2             3.5469e+06           9.882e+06                NaN
# EXTOT2              3.5469e+06          1.1304e+07                NaN
# EXCD2                      NaN                 NaN                NaN
# PERIOD                   FINAL               FINAL              FINAL
# YEAR                   2010/11             2010/11            2010/11
# VALTYPE                  AC-TR               AC-TR              AC-TR
#
#                     9        ...           1070984           1070985  \
# RECORD                   10  ...           1070985           1070986
# BBLE             1000041002  ...        5080500065        5080500068
# B                         1  ...                 5                 5
# BLOCK                     4  ...              8050              8050
# LOT                    1002  ...                65                68
# EASEMENT                NaN  ...               NaN               NaN
# OWNER     TRZ HOLDINGS, LLC  ...      THOMAS BROWN     DEBRA AMAROSO
# BLDGCL                   R5  ...                A1                A1
# TAXCLASS                  4  ...                 1                 1
# LTFRONT                   0  ...                60                75
# LTDEPTH                   0  ...               127               127
# EXT                     NaN  ...                 G                 G
# STORIES                  50  ...               2.5               2.5
# FULLVAL         5.70093e+06  ...            463000            498000
# AVLAND               919276  ...             14557             15916
# AVTOT           2.56542e+06  ...             23566             25988
# EXLAND                    0  ...              1620              1620
# EXTOT                     0  ...              1620              1620
# EXCD1                   NaN  ...              1017              1017
# STADDR       1 WATER STREET  ...  552 CRAIG AVENUE  546 CRAIG AVENUE
# ZIP                   10004  ...             10307             10307
# EXMPTCL                 NaN  ...               NaN               NaN
# BLDFRONT                  0  ...                25                26
# BLDDEPTH                  0  ...                43                28
# AVLAND2              919276  ...               NaN               NaN
# AVTOT2          2.96162e+06  ...               NaN               NaN
# EXLAND2                 NaN  ...               NaN               NaN
# EXTOT2                  NaN  ...               NaN               NaN
# EXCD2                   NaN  ...               NaN               NaN
# PERIOD                FINAL  ...             FINAL             FINAL
# YEAR                2010/11  ...           2010/11           2010/11
# VALTYPE               AC-TR  ...             AC-TR             AC-TR
#
#                    1070986           1070987           1070988  \
# RECORD             1070987           1070988           1070989
# BBLE            5080500072        5080500076        5080500078
# B                        5                 5                 5
# BLOCK                 8050              8050              8050
# LOT                     72                76                78
# EASEMENT               NaN               NaN               NaN
# OWNER      JOSEPH R GLORIA    DENNIS EMPEROR        CHIU, ANNE
# BLDGCL                  A1                A1                A3
# TAXCLASS                 1                 1                 1
# LTFRONT                 75                33               103
# LTDEPTH                116               116                85
# EXT                    NaN                 G               NaN
# STORIES                  2               2.5                 2
# FULLVAL             669000            397000            569000
# AVLAND               22800             12104              6379
# AVTOT                40140             20449             30246
# EXLAND                1620              4687                 0
# EXTOT                 1620              4687                 0
# EXCD1                 1017              1010               NaN
# STADDR    536 CRAIG AVENUE  534 CRAIG AVENUE  532 CRAIG AVENUE
# ZIP                  10307             10307             10307
# EXMPTCL                NaN               NaN               NaN
# BLDFRONT                30                16                39
# BLDDEPTH                40                39                56
# AVLAND2                NaN               NaN               NaN
# AVTOT2                 NaN               NaN               NaN
# EXLAND2                NaN               NaN               NaN
# EXTOT2                 NaN               NaN               NaN
# EXCD2                  NaN              1017               NaN
# PERIOD               FINAL             FINAL             FINAL
# YEAR               2010/11           2010/11           2010/11
# VALTYPE              AC-TR             AC-TR             AC-TR
#
#                      1070989             1070990             1070991  \
# RECORD               1070990             1070991             1070992
# BBLE              5080500083          5080500086          5080500089
# B                          5                   5                   5
# BLOCK                   8050                8050                8050
# LOT                       83                  86                  89
# EASEMENT                 NaN                 NaN                 NaN
# OWNER            TOBIN, GALE    SHERRI MILINAZZO        JOHN GERVASI
# BLDGCL                    A1                  A1                  A1
# TAXCLASS                   1                   1                   1
# LTFRONT                   60                  62                  53
# LTDEPTH                  120                 228                 273
# EXT                      NaN                 NaN                   G
# STORIES                  2.5                 2.5                   2
# FULLVAL               438000              544000              480000
# AVLAND                 14536                9303               14790
# AVTOT                  23322               14929               22975
# EXLAND                  1620                1620               14728
# EXTOT                   1620                1620               14728
# EXCD1                   1017                1017                1015
# STADDR    142 BENTLEY STREET  146 BENTLEY STREET  150 BENTLEY STREET
# ZIP                    10307               10307               10307
# EXMPTCL                  NaN                 NaN                 NaN
# BLDFRONT                  30                  32                  24
# BLDDEPTH                  26                  26                  32
# AVLAND2                  NaN                 NaN                 NaN
# AVTOT2                   NaN                 NaN                 NaN
# EXLAND2                  NaN                 NaN                 NaN
# EXTOT2                   NaN                 NaN                 NaN
# EXCD2                    NaN                 NaN                1017
# PERIOD                 FINAL               FINAL               FINAL
# YEAR                 2010/11             2010/11             2010/11
# VALTYPE                AC-TR               AC-TR               AC-TR
#
#                      1070992             1070993
# RECORD               1070993             1070994
# BBLE              5080500092          5080500094
# B                          5                   5
# BLOCK                   8050                8050
# LOT                       92                  94
# EASEMENT                 NaN                 NaN
# OWNER            RITA M MOOG      EDWARD DONOHUE
# BLDGCL                    A1                  A1
# TAXCLASS                   1                   1
# LTFRONT                   52                  50
# LTDEPTH                  136                  80
# EXT                      NaN                 NaN
# STORIES                    2                   2
# FULLVAL               543000              473000
# AVLAND                 12388               14061
# AVTOT                  23037               22394
# EXLAND                  1620                1620
# EXTOT                   1620                1620
# EXCD1                   1017                1017
# STADDR    156 BENTLEY STREET  162 BENTLEY STREET
# ZIP                    10307               10307
# EXMPTCL                  NaN                 NaN
# BLDFRONT                  32                  30
# BLDDEPTH                  21                  24
# AVLAND2                  NaN                 NaN
# AVTOT2                   NaN                 NaN
# EXLAND2                  NaN                 NaN
# EXTOT2                   NaN                 NaN
# EXCD2                    NaN                 NaN
# PERIOD                 FINAL               FINAL
# YEAR                 2010/11             2010/11
# VALTYPE                AC-TR               AC-TR
#
# [32 rows x 1070994 columns]

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='B', data = mydata)
plt.savefig('hist.png')

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=1.5)
plot = sns.countplot(x='EXCD2', data = mydata, order = mydata['BLOCK'].value_counts().head(15).index)

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=1.5)
plot = sns.countplot(x='EXCD2', data = mydata, order = mydata['EXCD2'].value_counts().head(10).index)

# %%
mydata[mydata['EXTOT2']<=100000]['EXTOT2'].count()/numrecords
# Out:
# 0.09029462349929131

# %%
tmp = []
name = []

# %%
for i in ['B','BLOCK','LOT','EASEMENT','OWNER','BLDGCL','TAXCLASS','EXT','STORIES','EXCD1','STADDR','ZIP','EXMPTCL','EXCD2']:
    tmp.append(len(mydata[i].unique())
tmp = pd.Series(tmp)
name = pd.Series(name)
# Out:
#   File "<ipython-input-289-f994a1aff0a9>", line 3
#     tmp = pd.Series(tmp)
#       ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame()

# %%
df['name'] = name
df['Columns'] = tmp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-285-0d61cbf0b2e3> in <module>
# ----> 1 df['name'] = name
#       2 df['Columns'] = tmp
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3470         klass = self._constructor_sliced
#    3471         return klass(values, index=self.index, name=items, fastpath=True)
# -> 3472
#    3473     def __setitem__(self, key, value):
#    3474         key = com.apply_if_callable(key, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3547
#    3548             self._data = self._data.reindex_axis(
# -> 3549                 value.index.copy(), axis=1, fill_value=np.nan
#    3550             )
#    3551
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3732                 loc = self.columns.get_loc(key)
#    3733                 if isinstance(loc, (slice, Series, np.ndarray, Index)):
# -> 3734                     cols = maybe_droplevels(self.columns[loc], key)
#    3735                     if len(cols) and not cols.equals(value.columns):
#    3736                         value = value.reindex(cols, axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
df
# Out:
#         name  Columns
# 0          B  1070994
# 1      BLOCK  1070994
# 2        LOT  1070994
# 3   EASEMENT     4636
# 4      OWNER  1039249
# 5     BLDGCL  1070994
# 6   TAXCLASS  1070994
# 7        EXT   354305
# 8    STORIES  1014730
# 9      EXCD1   638488
# 10    STADDR  1070318
# 11       ZIP  1041104
# 12   EXMPTCL    15579
# 13     EXCD2    92948

# %%
a = ['B','BLOCK','LOT','EASEMENT','OWNER','BLDGCL','TAXCLASS','EXT','STORIES','EXCD1','STADDR','ZIP','EXMPTCL','EXCD2']

# %%
for i in a:
    print(len(mydata[i].unique())
# Out:
#   File "<ipython-input-7-6ba5ccd6c762>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
tmp = []
